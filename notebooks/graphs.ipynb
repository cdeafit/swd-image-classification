# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cdict = {0: 'green', -1: 'red', 0.5: 'blue'}
path = '/content/drive/MyDrive/sdw_classification/documents/figures/'

# %%
log_tunedrescale_regular_acc = np.array([0.6973, 0.7010, 0.6599, 0.6750, 0.6748])
log_tunedrescale_pca_acc = [0.6973, 0.7047, 0.6687, 0.6762, 0.6625]
log_tunedrescale_pca80_acc = [0.7035, 0.6924, 0.6934, 0.7009, 0.6909]
log_tunedrescale_nmf_acc = [0.7159, 0.7233, 0.7009, 0.7133, 0.7058]

log_tunedrescale_regular_auc = np.array([0.7506, 0.7543, 0.6947, 0.7160, 0.7147])
log_tunedrescale_pca_auc = [0.7507, 0.7574, 0.7057, 0.7280, 0.7232]
log_tunedrescale_pca80_auc = [0.7589, 0.7520, 0.7367, 0.7481, 0.7468]
log_tunedrescale_nmf_auc = [0.7593, 0.7608, 0.7550, 0.7545, 0.7607]

log_tunedrescale_regular_over = [0, -1, -1, -1, -1]
log_tunedrescale_pca_over = [0, -1, -1, -1, -1]
log_tunedrescale_pca80_over = [0, 0, 0, 0, 0]
log_tunedrescale_nmf_over = [0, 0, 0, 0, 0]

dim_sizes = [10, 30, 50, 75, 100]

# %%
# Accuracy

fig, ax = plt.subplots(figsize = (10, 10))

for idx in range(5):
  ax.scatter(dim_sizes[idx], log_tunedrescale_regular_acc[idx], c = cdict[log_tunedrescale_regular_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunedrescale_pca_acc[idx], c = cdict[log_tunedrescale_pca_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunedrescale_pca80_acc[idx], c = cdict[log_tunedrescale_pca80_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunedrescale_nmf_acc[idx], c = cdict[log_tunedrescale_nmf_over[idx]], s = 200)

plt.title('Logistic Regresion with Tuned Hyperparameters and Rescaled Pixels', fontsize=14)
plt.xlabel('Training examples', fontsize=14)
plt.ylabel('accuracy', fontsize=14)
plt.grid()

plt.plot(dim_sizes, log_tunedrescale_regular_acc, '-', color='b',
            label="Regular Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunedrescale_pca_acc, '-', color="g",
            label="PCA Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunedrescale_pca80_acc, '-', color="y",
            label="PCA 80% Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunedrescale_nmf_acc, '-', color="k",
            label="NMF Dataset", linewidth=3)
plt.legend(loc="best", fontsize=14)
plt.show()
fig.savefig(fname = path + 'log_tunedrescale_acc', dpi = 400)

# %%
# AUC

fig, ax = plt.subplots(figsize = (10, 10))

for idx in range(5):
  ax.scatter(dim_sizes[idx], log_tunedrescale_regular_auc[idx], c = cdict[log_tunedrescale_regular_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunedrescale_pca_auc[idx], c = cdict[log_tunedrescale_pca_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunedrescale_pca80_auc[idx], c = cdict[log_tunedrescale_pca80_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunedrescale_nmf_auc[idx], c = cdict[log_tunedrescale_nmf_over[idx]], s = 200)

plt.title('Logistic Regresion with Tuned Hyperparameters and Rescaled Pixels', fontsize=14)
plt.xlabel('Training examples', fontsize=14)
plt.ylabel('AUC', fontsize=14)
plt.grid()

plt.plot(dim_sizes, log_tunedrescale_regular_auc, '-', color='b',
            label="Regular Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunedrescale_pca_auc, '-', color="g",
            label="PCA Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunedrescale_pca80_auc, '-', color="y",
            label="PCA 80% Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunedrescale_nmf_auc, '-', color="k",
            label="NMF Dataset", linewidth=3)
plt.legend(loc="best", fontsize=14)
plt.show()

fig.savefig(fname = path + 'log_tunedrescale_AUC', dpi = 400)

# %%
log_tunededgesrescale_regular_acc = [0.6699, 0.7591, 0.8051, 0.8101, 0.8163]
log_tunededgesrescale_pca_acc = [0.6699, 0.7591, 0.8051, 0.8101, 0.8163]
log_tunededgesrescale_pca80_acc = [0.6712, 0.7555, 0.7369, 0.7369, 0.7283]
log_tunededgesrescale_nmf_acc = [0.6872, 0.7443, 0.7282, 0.7084, 0.6798]

log_tunededgesrescale_regular_auc = [0.7178, 0.8499, 0.8846, 0.8791, 0.8867]
log_tunededgesrescale_pca_auc = [0.7178, 0.8499, 0.8846, 0.8791, 0.8867]
log_tunededgesrescale_pca80_auc = [0.7343, 0.8286, 0.8309, 0.7849, 0.7665]
log_tunededgesrescale_nmf_auc = [0.7424, 0.8304, 0.8193, 0.8195, 0.8026]

log_tunededgesrescale_regular_over = [0, -1, -1, -1, -1]
log_tunededgesrescale_pca_over = [0, -1, -1, -1, -1]
log_tunededgesrescale_pca80_over = [0, -1, -1, -1, -1]
log_tunededgesrescale_nmf_over = [0, 0, -1, 0.5, 0.5]

# %%
# Accuracy

fig, ax = plt.subplots(figsize = (10, 10))

for idx in range(5):
  ax.scatter(dim_sizes[idx], log_tunededgesrescale_regular_acc[idx], c = cdict[log_tunededgesrescale_regular_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededgesrescale_pca_acc[idx], c = cdict[log_tunededgesrescale_pca_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededgesrescale_pca80_acc[idx], c = cdict[log_tunededgesrescale_pca80_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededgesrescale_nmf_acc[idx], c = cdict[log_tunededgesrescale_nmf_over[idx]], s = 200)

plt.title('Logistic Regresion with Tuned Hyperparameters, Rescaled Pixels and Edges filtered', fontsize=14)
plt.xlabel('Training examples', fontsize=14)
plt.ylabel('accuracy', fontsize=14)
plt.grid()

plt.plot(dim_sizes, log_tunededgesrescale_regular_acc, '-', color='b',
            label="Regular Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededgesrescale_pca_acc, '-', color="g",
            label="PCA Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededgesrescale_pca80_acc, '-', color="y",
            label="PCA 80% Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededgesrescale_nmf_acc, '-', color="k",
            label="NMF Dataset", linewidth=3)
plt.legend(loc="best", fontsize=14)
plt.show()

fig.savefig(fname = path + 'log_tunededgesrescale_acc', dpi = 400)

# %%
# Accuracy

fig, ax = plt.subplots(figsize = (10, 10))

for idx in range(5):
  ax.scatter(dim_sizes[idx], log_tunededgesrescale_regular_auc[idx], c = cdict[log_tunededgesrescale_regular_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededgesrescale_pca_auc[idx], c = cdict[log_tunededgesrescale_pca_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededgesrescale_pca80_auc[idx], c = cdict[log_tunededgesrescale_pca80_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededgesrescale_nmf_auc[idx], c = cdict[log_tunededgesrescale_nmf_over[idx]], s = 200)

plt.title('Logistic Regresion with Tuned Hyperparameters, Rescaled Pixels and Edges filtered', fontsize=14)
plt.xlabel('Training examples', fontsize=14)
plt.ylabel('AUC', fontsize=14)
plt.grid()

plt.plot(dim_sizes, log_tunededgesrescale_regular_auc, '-', color='b',
            label="Regular Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededgesrescale_pca_auc, '-', color="g",
            label="PCA Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededgesrescale_pca80_auc, '-', color="y",
            label="PCA 80% Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededgesrescale_nmf_auc, '-', color="k",
            label="NMF Dataset", linewidth=3)
plt.legend(loc="best", fontsize=14)
plt.show()

fig.savefig(fname = path + 'log_tunededgesrescale_AUC', dpi = 400)

# %%
log_tunededges_regular_acc = [0.6514, 0.7047, 0.7318, 0.7518, 0.7457]
log_tunededges_pca_acc = [0.6514, 0.7494, 0.8039, 0.7742, 0.7966]
log_tunededges_pca80_acc = [0.6811, 0.7270, 0.7431, 0.7084, 0.7096]
log_tunededges_nmf_acc = [0.6750, 0.7630, 0.7293, 0.7047, 0.6873]

log_tunededges_regular_auc = [0.7236, 0.7497, 0.7967, 0.8218, 0.8271]
log_tunededges_pca_auc = [0.7236, 0.8183, 0.8785, 0.8576, 0.8690]
log_tunededges_pca80_auc = [0.7396, 0.7754, 0.8133, 0.7502, 0.7425]
log_tunededges_nmf_auc = [0.7379, 0.8087, 0.8103, 0.7714, 0.7620]

log_tunededges_regular_over = [0, -1, -1, -1, -1]
log_tunededges_pca_over = [0, -1, -1, -1, -1]
log_tunededges_pca80_over = [0, -1, -1, -1, -1]
log_tunededges_nmf_over = [0, 0.5, 0.5, -1, -1]

# %%
# Accuracy

fig, ax = plt.subplots(figsize = (10, 10))

for idx in range(5):
  ax.scatter(dim_sizes[idx], log_tunededges_regular_acc[idx], c = cdict[log_tunededges_regular_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededges_pca_acc[idx], c = cdict[log_tunededges_pca_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededges_pca80_acc[idx], c = cdict[log_tunededges_pca80_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededges_nmf_acc[idx], c = cdict[log_tunededges_nmf_over[idx]], s = 200)

plt.title('Logistic Regresion with Tuned Hyperparameters and Edges filtered', fontsize=14)
plt.xlabel('Training examples', fontsize=14)
plt.ylabel('accuracy', fontsize=14)
plt.grid()

plt.plot(dim_sizes, log_tunededges_regular_acc, '-', color='b',
            label="Regular Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededges_pca_acc, '-', color="g",
            label="PCA Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededges_pca80_acc, '-', color="y",
            label="PCA 80% Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededges_nmf_acc, '-', color="k",
            label="NMF Dataset", linewidth=3)
plt.legend(loc="best", fontsize=14)
plt.show()

fig.savefig(fname = path + 'log_tunededges_acc', dpi = 400)

# %%
# Accuracy

fig, ax = plt.subplots(figsize = (10, 10))

for idx in range(5):
  ax.scatter(dim_sizes[idx], log_tunededges_regular_auc[idx], c = cdict[log_tunededges_regular_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededges_pca_auc[idx], c = cdict[log_tunededges_pca_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededges_pca80_auc[idx], c = cdict[log_tunededges_pca80_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_tunededges_nmf_auc[idx], c = cdict[log_tunededges_nmf_over[idx]], s = 200)

plt.title('Logistic Regresion with Tuned Hyperparameters and Edges filtered', fontsize=14)
plt.xlabel('Training examples', fontsize=14)
plt.ylabel('AUC', fontsize=14)
plt.grid()

plt.plot(dim_sizes, log_tunededges_regular_auc, '-', color='b',
            label="Regular Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededges_pca_auc, '-', color="g",
            label="PCA Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededges_pca80_auc, '-', color="y",
            label="PCA 80% Dataset", linewidth=3)
plt.plot(dim_sizes, log_tunededges_nmf_auc, '-', color="k",
            label="NMF Dataset", linewidth=3)
plt.legend(loc="best", fontsize=14)
plt.show()

fig.savefig(fname = path + 'log_tunededges_AUC', dpi = 400)

# %%
log_regular_acc = [0.6499, 0.6525, 0.63, 0.6180, 0.6317]
log_pca_acc = [0.6574, 0.6847, 0.6275, 0.6353, 0.6528]
log_pca80_acc = [0.6946, 0.7010, 0.6871, 0.6899, 0.6873]
log_nmf_acc = [0.6724, 0.6898, 0.6971, 0.6788, 0.6984]

log_regular_auc = [0.6961, 0.7123, 0.6647, 0.6722, 0.6634]
log_pca_auc = [0.7024, 0.7231, 0.6866, 0.6802, 0.6937]
log_pca80_auc = [0.7406, 0.7519, 0.7431, 0.7370, 0.7441]
log_nmf_auc = [0.7287, 0.7569, 0.7542, 0.7485, 0.7556]

log_regular_over = [0, -1, -1, -1, -1]
log_pca_over = [0, -1, -1, -1, -1]
log_pca80_over = [0, 0, 0, 0, 0]
log_nmf_over = [0, 0, 0, 0, 0]

# %%
# Accuracy

fig, ax = plt.subplots(figsize = (10, 10))

for idx in range(5):
  ax.scatter(dim_sizes[idx], log_regular_acc[idx], c = cdict[log_regular_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_pca_acc[idx], c = cdict[log_pca_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_pca80_acc[idx], c = cdict[log_pca80_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_nmf_acc[idx], c = cdict[log_nmf_over[idx]], s = 200)

plt.title('Logistic Regresion', fontsize=14)
plt.xlabel('Training examples', fontsize=14)
plt.ylabel('accuracy', fontsize=14)
plt.grid()

plt.plot(dim_sizes, log_regular_acc, '-', color='b',
            label="Regular Dataset", linewidth=3)
plt.plot(dim_sizes, log_pca_acc, '-', color="g",
            label="PCA Dataset", linewidth=3)
plt.plot(dim_sizes, log_pca80_acc, '-', color="y",
            label="PCA 80% Dataset", linewidth=3)
plt.plot(dim_sizes, log_nmf_acc, '-', color="k",
            label="NMF Dataset", linewidth=3)
plt.legend(loc="best", fontsize=14)
plt.show()

fig.savefig(fname = path + 'log_acc', dpi = 400)

# %%
# AUC

fig, ax = plt.subplots(figsize = (10, 10))

for idx in range(5):
  ax.scatter(dim_sizes[idx], log_regular_auc[idx], c = cdict[log_regular_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_pca_auc[idx], c = cdict[log_pca_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_pca80_auc[idx], c = cdict[log_pca80_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], log_nmf_auc[idx], c = cdict[log_nmf_over[idx]], s = 200)

plt.title('Logistic Regresion', fontsize=14)
plt.xlabel('Training examples', fontsize=14)
plt.ylabel('AUC', fontsize=14)
plt.grid()

plt.plot(dim_sizes, log_regular_auc, '-', color='b',
            label="Regular Dataset", linewidth=3)
plt.plot(dim_sizes, log_pca_auc, '-', color="g",
            label="PCA Dataset", linewidth=3)
plt.plot(dim_sizes, log_pca80_auc, '-', color="y",
            label="PCA 80% Dataset", linewidth=3)
plt.plot(dim_sizes, log_nmf_auc, '-', color="k",
            label="NMF Dataset", linewidth=3)
plt.legend(loc="best", fontsize=14)
plt.show()

fig.savefig(fname = path + 'log_AUC', dpi = 400)

# %%
knn_tunededgesrescale_regular_acc = [0.6935, 0.5210, 0.5024, 0.5]
knn_tunededgesrescale_pca_acc = [0.7022, 0.5260, 0.5037, 0.5]
knn_tunededgesrescale_pca80_acc = [0.7108, 0.7282, 0.7358, 0.7246]
knn_tunededgesrescale_nmf_acc = [0.7170, 0.66, 0.6178, 0.5843]

knn_tunededgesrescale_regular_auc = [0.7361, 0.6491, 0.6244, 0.6338]
knn_tunededgesrescale_pca_auc = [0.7497, 0.6594, 0.6410, 0.6353]
knn_tunededgesrescale_pca80_auc = [0.7696, 0.8496, 0.8388, 0.8585]
knn_tunededgesrescale_nmf_auc = [0.7694, 0.7423, 0.6788, 0.6864]

knn_tunededgesrescale_regular_over = [0, -1, -1, -1]
knn_tunededgesrescale_pca_over = [0, -1, -1, -1]
knn_tunededgesrescale_pca80_over = [0, 0, 0, 0]
knn_tunededgesrescale_nmf_over = [0, 0, 0, 0]

# %%
# Accuracy

fig, ax = plt.subplots(figsize = (10, 10))

for idx in range(4):
  ax.scatter(dim_sizes[idx], knn_tunededgesrescale_regular_acc[idx], c = cdict[knn_tunededgesrescale_regular_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], knn_tunededgesrescale_pca_acc[idx], c = cdict[knn_tunededgesrescale_pca_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], knn_tunededgesrescale_pca80_acc[idx], c = cdict[knn_tunededgesrescale_pca80_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], knn_tunededgesrescale_nmf_acc[idx], c = cdict[knn_tunededgesrescale_nmf_over[idx]], s = 200)

plt.title('K Nearest Neighbors with Tuned Hyperparameters, Rescaled Pixels and Edges filtered', fontsize=14)
plt.xlabel('Training examples', fontsize=14)
plt.ylabel('accuracy', fontsize=14)
plt.grid()

plt.plot(dim_sizes[:4], knn_tunededgesrescale_regular_acc, '-', color='b',
            label="Regular Dataset", linewidth=3)
plt.plot(dim_sizes[:4], knn_tunededgesrescale_pca_acc, '-', color="g",
            label="PCA Dataset", linewidth=3)
plt.plot(dim_sizes[:4], knn_tunededgesrescale_pca80_acc, '-', color="y",
            label="PCA 80% Dataset", linewidth=3)
plt.plot(dim_sizes[:4], knn_tunededgesrescale_nmf_acc, '-', color="k",
            label="NMF Dataset", linewidth=3)
plt.legend(loc="best", fontsize=14)
plt.show()

fig.savefig(fname = path + 'knn_tunededgesrescale_acc', dpi = 400)

# %%
# AUC

fig, ax = plt.subplots(figsize = (10, 10))

for idx in range(4):
  ax.scatter(dim_sizes[idx], knn_tunededgesrescale_regular_auc[idx], c = cdict[knn_tunededgesrescale_regular_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], knn_tunededgesrescale_pca_auc[idx], c = cdict[knn_tunededgesrescale_pca_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], knn_tunededgesrescale_pca80_auc[idx], c = cdict[knn_tunededgesrescale_pca80_over[idx]], s = 200)
  ax.scatter(dim_sizes[idx], knn_tunededgesrescale_nmf_auc[idx], c = cdict[knn_tunededgesrescale_nmf_over[idx]], s = 200)

plt.title('K Nearest Neighbors with Tuned Hyperparameters, Rescaled Pixels and Edges filtered', fontsize=14)
plt.xlabel('Training examples', fontsize=14)
plt.ylabel('AUC', fontsize=14)
plt.grid()

plt.plot(dim_sizes[:4], knn_tunededgesrescale_regular_auc, '-', color='b',
            label="Regular Dataset", linewidth=3)
plt.plot(dim_sizes[:4], knn_tunededgesrescale_pca_auc, '-', color="g",
            label="PCA Dataset", linewidth=3)
plt.plot(dim_sizes[:4], knn_tunededgesrescale_pca80_auc, '-', color="y",
            label="PCA 80% Dataset", linewidth=3)
plt.plot(dim_sizes[:4], knn_tunededgesrescale_nmf_auc, '-', color="k",
            label="NMF Dataset", linewidth=3)
plt.legend(loc="best", fontsize=14)
plt.show()

fig.savefig(fname = path + 'knn_tunededgesrescale_AUC', dpi = 400)
